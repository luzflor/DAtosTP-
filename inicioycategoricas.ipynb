# %% [markdown]
# Analisis exploratorio de datos con Python

# %% [markdown]
# Tp1 - EDA y Visualizacion

# %% [markdown]
# Carga inicial de datos

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Entrenamieto_ECI_2020.csv')

# %%
df.head()
# Out:
#       ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0  27761      EMEA        None                                   1
# 1  27760      EMEA        None                                   0
# 2  27446  Americas  NW America                                   0
# 3  16808  Americas  NW America                                   1
# 4  16805  Americas  NW America                                   1
#
#    Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 0                                 1                             1
# 1                                 0                             0
# 2                                 0                             0
# 3                                 0                             1
# 4                                 0                             1
#
#    Bureaucratic_Code_0_Approved  Submitted_for_Approval    Bureaucratic_Code  \
# 0                             1                       0  Bureaucratic_Code_4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 52 columns):
# ID                                    16947 non-null int64
# Region                                16947 non-null object
# Territory                             16947 non-null object
# Pricing, Delivery_Terms_Quote_Appr    16947 non-null int64
# Pricing, Delivery_Terms_Approved      16947 non-null int64
# Bureaucratic_Code_0_Approval          16947 non-null int64
# Bureaucratic_Code_0_Approved          16947 non-null int64
# Submitted_for_Approval                16947 non-null int64
# Bureaucratic_Code                     16947 non-null object
# Account_Created_Date                  16947 non-null object
# Source                                16947 non-null object
# Billing_Country                       16947 non-null object
# Account_Name                          16947 non-null object
# Opportunity_Name                      16947 non-null object
# ...

# %% [markdown]
# Analisis de variables categoricas

# %%
regiones= df['Region']

# %%
regiones.value_counts()
# Out:
# Japan          4892
# EMEA           4664
# Americas       3945
# APAC           3262
# Middle East     184
# Name: Region, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Region', 'Territory', 'Pricing, Delivery_Terms_Quote_Appr',
#        'Pricing, Delivery_Terms_Approved', 'Bureaucratic_Code_0_Approval',
#        'Bureaucratic_Code_0_Approved', 'Submitted_for_Approval',
#        'Bureaucratic_Code', 'Account_Created_Date', 'Source ',
#        'Billing_Country', 'Account_Name', 'Opportunity_Name', 'Opportunity_ID',
#        'Sales_Contract_No', 'Account_Owner', 'Opportunity_Owner',
#        'Account_Type', 'Opportunity_Type', 'Quote_Type', 'Delivery_Terms',
#        'Opportunity_Created_Date', 'Brand', 'Product_Type', 'Size',
#        'Product_Category_B', 'Price', 'Currency', 'Last_Activity',
#        'Quote_Expiry_Date', 'Last_Modified_Date', 'Last_Modified_By',
#        'Product_Family', 'Product_Name', 'ASP_Currency', 'ASP',
#        'ASP_(converted)_Currency', 'ASP_(converted)',
#        'Planned_Delivery_Start_Date', 'Planned_Delivery_End_Date', 'Month',
#        'Delivery_Quarter', 'Delivery_Year', 'Actual_Delivery_Date', 'TRF',
# ...

# %%
territorios= df['Territory']

# %%
territorios.value_counts()
# Out:
# None                    4999
# Germany                 1682
# NW America              1568
# Australia               1208
# India                    809
# NE America               760
# Japan                    681
# Netherlands              533
# SE America               493
# France                   449
# Singapore                441
# United Kingdom           313
# Belgium                  285
# Italy                    283
# Spain                    268
# Central US               254
# China (PRC)              218
# SW America               206
# Thailand                 173
# Indonesia                154
# Austria                  145
# Philippines              109
# Jordan                   102
# Canada                    74
# Luxembourg                70
# Portugal                  66
# Poland                    60
# Vietnam                   51
# Cyprus                    44
# New Zealand               38
#                         ...
# Kazakhstan                 7
# ...

# %%
codigosburocraticos = df ['Bureaucratic_Code']

# %%
codigosburocraticos.value_counts()
# Out:
# Bureaucratic_Code_4    12587
# Bureaucratic_Code_5     3803
# Bureaucratic_Code_1      261
# Bureaucratic_Code_2      242
# Bureaucratic_Code_0       51
# Bureaucratic_Code_3        2
# Bureaucratic_Code_6        1
# Name: Bureaucratic_Code, dtype: int64

# %%
source= df['Source ']

# %%
source.value_counts()
# Out:
# None         9497
# Source_7     2965
# Source_9     1459
# Source_11    1421
# Source_13     786
# Source_3      418
# Source_1      137
# Source_10     106
# Source_2       86
# Source_4       43
# Source_6       19
# Source_0        7
# Source_12       2
# Source_5        1
# Name: Source , dtype: int64

# %%
 paisFactura= df['Billing_Country'].value_counts()

# %%
paisFactura
# Out:
# Japan                                         4879
# United States                                 3802
# Germany                                       1979
# Australia                                     1169
# India                                          672
# Netherlands                                    563
# Singapore                                      432
# France                                         396
# Spain                                          317
# Italy                                          295
# United Kingdom                                 284
# Belgium                                        226
# China                                          222
# Thailand                                       195
# Austria                                        145
# Indonesia                                      142
# Philippines                                    138
# Luxembourg                                     136
# ...

# %%
nombreCuentaCliente=df['Account_Name'].value_counts()

# %%
nombreCuentaCliente
# Out:
# Account_Name_1888    2124
# Account_Name_1836     886
# Account_Name_25       752
# Account_Name_1991     586
# Account_Name_1642     397
# Account_Name_1508     355
# Account_Name_1440     317
# Account_Name_533      283
# Account_Name_263      249
# Account_Name_660      231
# Account_Name_931      215
# Account_Name_1994     152
# Account_Name_1274     144
# Account_Name_271      131
# Account_Name_1757     127
# Account_Name_1693     125
# Account_Name_501      117
# Account_Name_1067     116
# Account_Name_1075     106
# Account_Name_1448     101
# Account_Name_1411      93
# Account_Name_266       91
# Account_Name_1794      91
# Account_Name_1378      89
# Account_Name_686       86
# Account_Name_1468      84
# Account_Name_1313      76
# Account_Name_5         75
# Account_Name_702       74
# Account_Name_1100      73
#                      ...
# Account_Name_905        1
# Account_Name_1959       1
# Account_Name_1598       1
# Account_Name_1733       1
# ...

# %%
nombreOportunidad = df['Opportunity_Name'].value_counts()

# %%
nombreOportunidad
# Out:
# Opportunity_Name_5036     36
# Opportunity_Name_9795     36
# Opportunity_Name_12179    26
# Opportunity_Name_11461    26
# Opportunity_Name_6835     24
# Opportunity_Name_1661     18
# Opportunity_Name_10944    16
# Opportunity_Name_9628     16
# Opportunity_Name_10131    16
# Opportunity_Name_4889     16
# Opportunity_Name_10945    16
# Opportunity_Name_10946    16
# Opportunity_Name_809      14
# Opportunity_Name_847      14
# Opportunity_Name_10928    14
# Opportunity_Name_10136    14
# Opportunity_Name_11230    13
# Opportunity_Name_9976     13
# Opportunity_Name_10929    13
# Opportunity_Name_10434    13
# Opportunity_Name_11914    12
# Opportunity_Name_4769     12
# Opportunity_Name_5331     12
# Opportunity_Name_4771     12
# Opportunity_Name_2380     12
# Opportunity_Name_10653    11
# Opportunity_Name_3422     11
# Opportunity_Name_257      11
# Opportunity_Name_12287    11
# Opportunity_Name_10951    11
#                           ..
# Opportunity_Name_1561      1
# ...

# %%
responsableCuenta = df['Account_Owner'].value_counts()

# %%
responsableCuenta
# Out:
# Person_Name_50    3730
# Person_Name_13    1328
# Person_Name_8     1286
# Person_Name_43    1241
# Person_Name_18    1093
# Person_Name_3      875
# Person_Name_32     682
# Person_Name_4      664
# Person_Name_65     631
# Person_Name_64     577
# Person_Name_16     439
# Person_Name_46     381
# Person_Name_45     357
# Person_Name_2      333
# Person_Name_38     326
# Person_Name_42     304
# Person_Name_66     258
# Person_Name_60     227
# Person_Name_49     201
# Person_Name_59     201
# Person_Name_62     179
# Person_Name_54     178
# Person_Name_52     172
# Person_Name_5      166
# Person_Name_21     166
# Person_Name_55     138
# Person_Name_63     138
# Person_Name_51     108
# Person_Name_39     104
# Person_Name_33      86
# Person_Name_14      74
# Person_Name_61      72
# Person_Name_44      57
# Person_Name_41      51
# Person_Name_9       50
# Person_Name_58      15
# Person_Name_26      12
# Person_Name_11      10
# Person_Name_29       8
# Person_Name_25       7
# ...

# %%
responsableOportunidad = df['Opportunity_Owner'].value_counts()

# %%
responsableOportunidad
# Out:
# Person_Name_50    3781
# Person_Name_8     1422
# Person_Name_13    1254
# Person_Name_18     982
# Person_Name_43     838
# Person_Name_3      832
# Person_Name_4      687
# Person_Name_32     686
# Person_Name_19     615
# Person_Name_64     516
# Person_Name_16     446
# Person_Name_23     422
# Person_Name_46     329
# Person_Name_65     322
# Person_Name_49     286
# Person_Name_48     256
# Person_Name_38     254
# Person_Name_66     243
# Person_Name_44     240
# Person_Name_39     211
# Person_Name_60     207
# Person_Name_62     174
# Person_Name_52     173
# Person_Name_54     171
# Person_Name_5      169
# Person_Name_59     134
# Person_Name_45     128
# Person_Name_2      118
# Person_Name_41     113
# Person_Name_51     111
# Person_Name_55      91
# Person_Name_33      87
# Person_Name_14      82
# Person_Name_11      77
# Person_Name_30      69
# Person_Name_63      67
# Person_Name_40      50
# Person_Name_25      49
# Person_Name_20      49
# Person_Name_22      43
# ...

# %%
tipoCuentaCliente = df ['Account_Type'].value_counts()

# %%
tipoCuentaCliente
# Out:
# Account_Type_2    8832
# Account_Type_0    5868
# Account_Type_5    1943
# Account_Type_1     165
# None               112
# Account_Type_6      17
# Account_Type_4      10
# Name: Account_Type, dtype: int64

# %%
tipoOportunidad = df['Opportunity_Type'].value_counts()

# %%
tipoOportunidad
# Out:
# Opportunity_Type_1     6819
# Opportunity_Type_7     5763
# Opportunity_Type_19    1900
# Opportunity_Type_8     1458
# Opportunity_Type_12     279
# Opportunity_Type_3      275
# Opportunity_Type_20     175
# Opportunity_Type_2       70
# Opportunity_Type_4       51
# Opportunity_Type_10      34
# Opportunity_Type_9       23
# Opportunity_Type_14      15
# Opportunity_Type_5       14
# Opportunity_Type_18      11
# Opportunity_Type_22      10
# Opportunity_Type_15       9
# Opportunity_Type_17       8
# Opportunity_Type_0        8
# Opportunity_Type_21       6
# Opportunity_Type_23       5
# Opportunity_Type_13       4
# Opportunity_Type_16       4
# Opportunity_Type_11       3
# Opportunity_Type_6        2
# Opportunity_Type_24       1
# Name: Opportunity_Type, dtype: int64

# %%
tipoPresupuesto= df['Quote_Type'].value_counts()

# %%
tipoPresupuesto
# Out:
# Non Binding    16777
# Binding          170
# Name: Quote_Type, dtype: int64

# %%
terminosEntrega = df['Delivery_Terms'].value_counts()

# %%
terminosEntrega
# Out:
# Delivery_Terms_4    7712
# Delivery_Terms_2    4633
# Delivery_Terms_1    2936
# Delivery_Terms_6     781
# Delivery_Terms_5     636
# Delivery_Terms_8     164
# Delivery_Terms_3      41
# Delivery_Terms_7      38
# Delivery_Terms_0       6
# Name: Delivery_Terms, dtype: int64

# %%
MarcaProducto= df['Brand'].value_counts()

# %%
MarcaProducto
# Out:
# None        15911
# Other         607
# Brand_9       140
# Brand_5        48
# Brand_24       38
# Brand_11       34
# Brand_25       24
# Brand_10       22
# Brand_22       20
# Brand_13       17
# Brand_7        17
# Brand_21       17
# Brand_20       10
# Brand_23       10
# Brand_27        5
# Brand_17        5
# Brand_0         4
# Brand_4         4
# Brand_2         4
# Brand_12        3
# Brand_16        2
# Brand_6         1
# Brand_1         1
# Brand_19        1
# Brand_26        1
# Brand_3         1
# Name: Brand, dtype: int64

# %%
tipoProducto= df['Product_Type'].value_counts()

# %%
tipoProducto
# Out:
# None              15935
# Other               515
# Product_Type_3      179
# Product_Type_1      142
# Product_Type_0       94
# Product_Type_4       73
# Product_Type_2        9
# Name: Product_Type, dtype: int64

# %%
tamanioProducto= df['Size'].value_counts()

# %%
tamanioProducto
# Out:
# None      15967
# Other       394
# Size_3      356
# Size_4      196
# Size_1       25
# Size_0        7
# Size_2        2
# Name: Size, dtype: int64

# %%
categaoriaBProducto= df['Product_Category_B'].value_counts()

# %%
categaoriaBProducto
# Out:
# None                     15928
# Other                      523
# Product_Category_B_2        59
# Product_Category_B_12       51
# Product_Category_B_7        47
# Product_Category_B_4        37
# Product_Category_B_5        36
# Product_Category_B_17       27
# Product_Category_B_1        24
# Product_Category_B_8        23
# Product_Category_B_3        23
# Product_Category_B_19       22
# Product_Category_B_11       21
# Product_Category_B_13       18
# Product_Category_B_16       17
# Product_Category_B_9        17
# Product_Category_B_24       16
# Product_Category_B_20        9
# Product_Category_B_6         9
# Product_Category_B_21        8
# Product_Category_B_15        8
# Product_Category_B_23        5
# Product_Category_B_26        4
# Product_Category_B_14        4
# Product_Category_B_0         3
# Product_Category_B_10        3
# Product_Category_B_27        3
# Product_Category_B_22        2
# Name: Product_Category_B, dtype: int64

# %%
moneda=df['Currency'].value_counts()

# %%
moneda
# Out:
# None    16052
# EUR       475
# USD       420
# Name: Currency, dtype: int64

# %%
familiaProducto=df['Product_Family'].value_counts()

# %%
familiaProducto
# Out:
# Product_Family_77     1345
# Product_Family_133    1249
# Product_Family_132     763
# Product_Family_212     636
# Product_Family_100     619
# Product_Family_85      596
# Product_Family_115     540
# Product_Family_226     524
# Product_Family_109     499
# Product_Family_208     478
# Product_Family_4       474
# Product_Family_128     436
# Product_Family_116     421
# Product_Family_164     419
# Product_Family_140     385
# Product_Family_209     381
# Product_Family_230     350
# Product_Family_29      345
# Product_Family_127     297
# Product_Family_139     278
# Product_Family_20      266
# Product_Family_213     259
# Product_Family_121     246
# Product_Family_170     238
# Product_Family_193     233
# Product_Family_73      217
# Product_Family_158     204
# Product_Family_201     180
# Product_Family_24      167
# Product_Family_0       165
#                       ...
# Product_Family_93        2
# Product_Family_242       1
# Product_Family_236       1
# ...

# %%
nombreProducto=df['Product_Name'].value_counts()

# %%
nombreProducto
# Out:
# Product_Name_100    976
# Product_Name_226    836
# Product_Name_231    579
# Product_Name_491    524
# Product_Name_4      474
# Product_Name_192    442
# Product_Name_111    388
# Product_Name_132    383
# Product_Name_495    350
# Product_Name_29     345
# Product_Name_148    340
# Product_Name_452    336
# Product_Name_167    333
# Product_Name_241    319
# Product_Name_220    317
# Product_Name_209    287
# Product_Name_20     266
# Product_Name_181    219
# Product_Name_439    212
# Product_Name_214    179
# Product_Name_246    178
# Product_Name_24     167
# Product_Name_0      165
# Product_Name_85     158
# Product_Name_23     157
# Product_Name_96     145
# Product_Name_448    131
# Product_Name_99     127
# Product_Name_128    122
# Product_Name_6      121
#                    ...
# Product_Name_53       1
# Product_Name_136      1
# Product_Name_207      1
# Product_Name_179      1
# Product_Name_475      1
# Product_Name_236      1
# Product_Name_235      1
# ...

# %%
nomedaPrecioPromedio=df['ASP_Currency'].value_counts()

# %%
nomedaPrecioPromedio
# Out:
# USD    7361
# JPY    4522
# EUR    4503
# AUD     556
# GBP       5
# Name: ASP_Currency, dtype: int64

# %%
nomedaPrecioPromedioVariable=df['ASP_(converted)_Currency'].value_counts()

# %%
nomedaPrecioPromedioVariable
# Out:
# USD    16947
# Name: ASP_(converted)_Currency, dtype: int64

# %%
trimestrePlaneadoEntrega=df['Delivery_Quarter'].value_counts()

# %%
trimestrePlaneadoEntrega
# Out:
# Q2    4443
# Q1    4317
# Q4    4144
# Q3    4043
# Name: Delivery_Quarter, dtype: int64

# %%
monedaMontoGravadoTotal=df['Total_Taxable_Amount_Currency'].value_counts()

# %%
monedaMontoGravadoTotal
# Out:
# USD    7347
# JPY    4525
# EUR    4518
# AUD     553
# GBP       4
# Name: Total_Taxable_Amount_Currency, dtype: int64

# %%
estado=df['Stage'].value_counts()

# %%
estado
# Out:
# Closed Won       9533
# Closed Lost      7350
# Proposal           35
# Negotiation        18
# Qualification      11
# Name: Stage, dtype: int64

# %%
categoriaAProducto=df['Prod_Category_A'].value_counts()

# %%
categoriaAProducto
# Out:
# Prod_Category_A_None    16947
# Name: Prod_Category_A, dtype: int64

# %% [markdown]
# Analisis de Oportunidad(Se retoma en notebook aparte)

# %%
oportunidad5036 = df.loc[df.Opportunity_Name.str.contains('Opportunity_Name_5036'),:]

# %%
oportunidad5036
# Out:
#           ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 16223  20112  Americas  NW America                                   1
# 16224  20115  Americas  NW America                                   1
# 16225  20118  Americas  NW America                                   1
# 16226  20122  Americas  NW America                                   1
# 16227  20125  Americas  NW America                                   1
# 16228  20128  Americas  NW America                                   1
# 16229  20132  Americas  NW America                                   1
# 16230  20135  Americas  NW America                                   1
# 16231  20138  Americas  NW America                                   1
# 16232  20141  Americas  NW America                                   1
# 16233  20145  Americas  NW America                                   1
# 16234  20151  Americas  NW America                                   1
# ...

# %%
###¿Por qué Total_Taxable_Amount es a veces mayor que Total_Amount?
###Cada fila del dataframe es un item de una oportunidad. Si agrupan por Opportunity_Name y suman los Total_Amount deberían llegar a Total_Taxable_Amount. Si esto no se cumple en todos, es algo para analizar en el TP.
